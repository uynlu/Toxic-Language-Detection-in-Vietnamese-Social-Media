# %%
import os

os.chdir("U:\\DataStorage\\UIT\\Researches\\DiscriminativeComments\\SourceCode")
print("Thư mục làm việc hiện tại: ", os.getcwd())
# Out:
# Thư mục làm việc hiện tại:  U:\DataStorage\UIT\Researches\DiscriminativeComments\SourceCode

# %% [markdown]
# # Import modules

# %%
from dataset.custom_dataset import CustomDataset

# %%
from model_running.model_utils.model_executor import ModelExecutor

# %% [markdown]
# # Custom data

# %%
train_data = CustomDataset(
    data_path=r"data\official\temp\splitting\train.json",
    label_type="toxicity",
    tokenizer_name="vinai/phobert-base-v2",
    cache_dir=r"model_checkpoints\pretrained_models\phobert",
    max_len=128
)
# Out:
# config.json:   0%|          | 0.00/678 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# bpe.codes: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
dev_data = CustomDataset(
    data_path=r"data\official\temp\splitting\dev.json",
    label_type="toxicity",
    tokenizer_name="vinai/phobert-base-v2",
    cache_dir=r"model_checkpoints\pretrained_models\phobert",
    max_len=128
)
