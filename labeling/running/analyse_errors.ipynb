# %%
import os

os.chdir("U:\\DataStorage\\UIT\\Researches\\DiscriminativeComments\\SourceCode")
print("Thư mục làm việc hiện tại: ", os.getcwd())
# Out:
# Thư mục làm việc hiện tại:  U:\DataStorage\UIT\Researches\DiscriminativeComments\SourceCode

# %% [markdown]
# # Import modules

# %%
from labeling.labeling_utils.errors_analysis import plot_different_labels_bar, plot_diffence_percentage, plot_diffence_percentage_each_category

# %% [markdown]
# # Analyse errors

# %% [markdown]
# ## Toxicity

# %% [markdown]
# ### Round 1

# %%
plot_different_labels_bar("data\\labelled\\sample_1\\round_1\\result\\differently_labelled\\different_labelled_data.json")

# %%
plot_diffence_percentage("data\\labelled\\sample_1\\round_1\\result\\differently_labelled\\different_labelled_data.json")

# %%
plot_diffence_percentage_each_category("data\\labelled\\sample_1\\round_1\\result\\differently_labelled\\different_labelled_data.json")
